# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mutual_fund= pd.read_csv("D:\Data Analytics\comprehensive_mutual_funds_data.csv")
mutual_fund
# Out:
#                                            scheme_name  min_sip  min_lumpsum  \
# 0    Aditya Birla SL Active Debt Multi-Mgr FoF-Dir ...      100          100
# 1                       Aditya Birla SL Arbitrage Fund     1000         1000
# 2       Aditya Birla SL Asset Allocator FoF-Dir Growth     1000         1000
# 3     Aditya Birla SL Bal Bhavishya Yojna – Dir Growth      500         1000
# 4              Aditya Birla SL Balanced Advantage Fund      100          100
# ..                                                 ...      ...          ...
# 809            UTI-Unit Linked Insurance Plan – Direct      500        15000
# 810                       UTI-Value Opportunities Fund      500         5000
# 811                       WhiteOak Capital Liquid Fund      500          500
# 812                    WhiteOak Capital Overnight Fund      500          500
# 813             WhiteOak Capital Ultra Short Term Fund      500          500
#
# ...

# %%
df=mutual_fund.copy()

# %%
df.head()
# Out:
#                                          scheme_name  min_sip  min_lumpsum  \
# 0  Aditya Birla SL Active Debt Multi-Mgr FoF-Dir ...      100          100
# 1                     Aditya Birla SL Arbitrage Fund     1000         1000
# 2     Aditya Birla SL Asset Allocator FoF-Dir Growth     1000         1000
# 3   Aditya Birla SL Bal Bhavishya Yojna – Dir Growth      500         1000
# 4            Aditya Birla SL Balanced Advantage Fund      100          100
#
#    expense_ratio  fund_size_cr  fund_age_yr        fund_manager sortino  \
# 0           0.27          10.0           10      Kaustubh Gupta    0.32
# 1           0.36        4288.0           10    Lovelish Solanki    1.33
# 2           0.53         157.0           10  Vinod Narayan Bhat    3.44
# 3           0.76         637.0            4         Atul Penkar    2.18
# 4           0.61        6386.0           10        Mohit Sharma    3.69
#
#    alpha     sd  beta sharpe  risk_level                           amc_name  \
# ...

# %%
df.columns
# Out:
# Index(['scheme_name', 'min_sip', 'min_lumpsum', 'expense_ratio',
#        'fund_size_cr', 'fund_age_yr', 'fund_manager', 'sortino', 'alpha', 'sd',
#        'beta', 'sharpe', 'risk_level', 'amc_name', 'rating', 'category',
#        'sub_category', 'returns_1yr', 'returns_3yr', 'returns_5yr'],
#       dtype='object')

# %%
df.shape
# Out:
# (814, 20)

# %%
null=df.isnull().sum()

# %%
null_col=null.loc[null>0]

# %%
null_col
# Out:
# returns_3yr     21
# returns_5yr    167
# dtype: int64

# %%
null_col.plot(kind='bar',color=['blue','Orange'])
plt.title('Null row number',fontsize=10)
plt.xlabel('Columns')
plt.ylabel('Count')
plt.show()

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['returns_3yr']=df['returns_3yr'].fillna(0)

# %%
df.isnull().sum()
# Out:
# scheme_name        0
# min_sip            0
# min_lumpsum        0
# expense_ratio      0
# fund_size_cr       0
# fund_age_yr        0
# fund_manager       0
# sortino            0
# alpha              0
# sd                 0
# beta               0
# sharpe             0
# risk_level         0
# amc_name           0
# rating             0
# category           0
# sub_category       0
# returns_1yr        0
# returns_3yr        0
# returns_5yr      167
# dtype: int64

# %%
df['returns_5yr']=df['returns_5yr'].fillna(0)

# %%
df.isnull().sum()
# Out:
# scheme_name      0
# min_sip          0
# min_lumpsum      0
# expense_ratio    0
# fund_size_cr     0
# fund_age_yr      0
# fund_manager     0
# sortino          0
# alpha            0
# sd               0
# beta             0
# sharpe           0
# risk_level       0
# amc_name         0
# rating           0
# category         0
# sub_category     0
# returns_1yr      0
# returns_3yr      0
# returns_5yr      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   scheme_name    814 non-null    object
#  1   min_sip        814 non-null    int64
#  2   min_lumpsum    814 non-null    int64
#  3   expense_ratio  814 non-null    float64
#  4   fund_size_cr   814 non-null    float64
#  5   fund_age_yr    814 non-null    int64
#  6   fund_manager   814 non-null    object
#  7   sortino        814 non-null    object
#  8   alpha          814 non-null    object
#  9   sd             814 non-null    object
#  10  beta           814 non-null    object
#  11  sharpe         814 non-null    object
#  12  risk_level     814 non-null    int64
#  13  amc_name       814 non-null    object
#  14  rating         814 non-null    int64
#  15  category       814 non-null    object
#  16  sub_category   814 non-null    object
# ...

# %%
df.head(2)
# Out:
#                                          scheme_name  min_sip  min_lumpsum  \
# 0  Aditya Birla SL Active Debt Multi-Mgr FoF-Dir ...      100          100
# 1                     Aditya Birla SL Arbitrage Fund     1000         1000
#
#    expense_ratio  fund_size_cr  fund_age_yr      fund_manager sortino alpha  \
# 0           0.27          10.0           10    Kaustubh Gupta    0.32  2.24
# 1           0.36        4288.0           10  Lovelish Solanki    1.33  1.53
#
#      sd  beta sharpe  risk_level                           amc_name  rating  \
# 0  9.39  0.01   0.24           3  Aditya Birla Sun Life Mutual Fund       3
# 1  0.72  0.56    1.1           1  Aditya Birla Sun Life Mutual Fund       3
#
#   category            sub_category  returns_1yr  returns_3yr  returns_5yr
# 0    Other           FoFs Domestic          4.0          6.5          6.9
# 1   Hybrid  Arbitrage Mutual Funds          5.6          4.8          5.5

# %%
data_type = df.dtypes.value_counts()
plt.figure(figsize=(25,10))
plt.title("Check Columns DataTypes", fontsize= 28)
plt.xlabel("DataTypes", fontsize= 25)
plt.ylabel("Count", fontsize= 25)


sns.barplot(x=data_type.index, y=data_type.values)
# Out:
# <Axes: title={'center': 'Check Columns DataTypes'}, xlabel='DataTypes', ylabel='Count'>

# %%
data_type = df.dtypes.value_counts()
data_type.plot(kind='bar',color=['red','green','black'])
plt.xlabel('Datatypes')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
data_type = df.dtypes.value_counts()

# %%
data_type
# Out:
# object     10
# int64       5
# float64     5
# dtype: int64

# %%
category=df.category.value_counts()
category
# Out:
# Equity               308
# Debt                 282
# Hybrid               116
# Other                 80
# Solution Oriented     28
# Name: category, dtype: int64

# %%
category.plot(kind='pie')
plt.title('Categorie Analysis')
plt.show()

# %%
plt.figure(figsize=(60,30))

plt.xticks(rotation=90,fontsize=15)
sns.countplot(x=df['sub_category'])
# Out:
# <Axes: xlabel='sub_category', ylabel='count'>

# %%
df.head(2)
# Out:
#                                          scheme_name  min_sip  min_lumpsum  \
# 0  Aditya Birla SL Active Debt Multi-Mgr FoF-Dir ...      100          100
# 1                     Aditya Birla SL Arbitrage Fund     1000         1000
#
#    expense_ratio  fund_size_cr  fund_age_yr      fund_manager sortino alpha  \
# 0           0.27          10.0           10    Kaustubh Gupta    0.32  2.24
# 1           0.36        4288.0           10  Lovelish Solanki    1.33  1.53
#
#      sd  beta sharpe  risk_level                           amc_name  rating  \
# 0  9.39  0.01   0.24           3  Aditya Birla Sun Life Mutual Fund       3
# 1  0.72  0.56    1.1           1  Aditya Birla Sun Life Mutual Fund       3
#
#   category            sub_category  returns_1yr  returns_3yr  returns_5yr
# 0    Other           FoFs Domestic          4.0          6.5          6.9
# 1   Hybrid  Arbitrage Mutual Funds          5.6          4.8          5.5

# %%
year_1=df.groupby('category')['returns_1yr'].mean()
year_3=df.groupby('category')['returns_3yr'].mean()
year_5=df.groupby('category')['returns_5yr'].mean()
year_1
# Out:
# category
# Debt                  4.823050
# Equity               10.110390
# Hybrid                7.027586
# Other                 8.568750
# Solution Oriented     5.917857
# Name: returns_5yr, dtype: float64

# %%
year_3
# Out:
# category
# Debt                  5.808865
# Equity               29.641558
# Hybrid               15.272414
# Other                20.532500
# Solution Oriented    18.167857
# Name: returns_3yr, dtype: float64

# %%
year_5
# Out:
# category
# Debt                  4.823050
# Equity               10.110390
# Hybrid                7.027586
# Other                 8.568750
# Solution Oriented     5.917857
# Name: returns_5yr, dtype: float64

# %%
plt.figure(figsize=(25,10))
plt.title('Categorization Average Returns')
plt.xlabel('Category')


sns.lineplot(x=year_1.index,y=year_1.values,color='b',marker='o',linestyle='--',markersize=20)
sns.lineplot(x=year_3.index,y=year_3.values,color='black',marker='o',linestyle='--',markersize=20)
sns.lineplot(x=year_5.index,y=year_5.values,color='g',marker='o',linestyle='--',markersize=20)
plt.
# Out:
# <Axes: title={'center': 'Categorization Average Returns'}, xlabel='Category'>
